# %%
import pandas as pd

df = pd.read_csv(r"E:\KULIAH\SEMESTER 3\IPDS\Movie_classification.csv")

dictionary = df.to_dict(orient='list')
print(dictionary)
# Out:
# {'Marketing expense': ['201.264', '205.462', '205.458', '206.474', '21.381', '20.597', '217.658', '22.891', '242.248', '234.008', '244.978', '223.494', '218.756', '325.952', '327.592', '325.478', '410.786', '35.684', '360.542', '34.516', '450.358', '370.408', '446.494', '397.686', '350.052', '368.108', '334.382', '391.154', '354.598', '40.049', '426.162', '470.944', '477.598', '430.344', '522.564', '212.834', '219.488', '216.028', '23.501', '205.526', '206.718', '225.488', '22.83', '231.872', '224.538', '234.284', '237.672', '245.854', '250.774', '243.954', '217.746', '208.674', '21.072', '209.962', '20.272', '202.622', '20.411', '202.864', '23.089', '220.656', '229.864', '234.342', '222.054', '22.53', '203.902', '207.168', '208.758', '211.578', '227.108', '225.632', '217.652', '231.752', '218.328', '239.078', '215.792', '219.024', '220.306', '217.414', '211.292', '216.774', '208.226', '208.924', '207.318', '207.102', '210.118', '21.147', '210.376', '214.302', '21.132', '210.604', '2
# ...

# %% [markdown]
# 1. Cek nilai duplikat dan hapus nilai duplikat tersebut

# %%
new_list = list(set(df))

print(new_list)
# Out:
# ['Start_Tech_Oscar', 'Lead_Actress_rating', 'Num_multiplex', 'Marketing expense', 'Twitter_hastags', 'Multiplex coverage', 'Genre', 'Director_rating', 'Collection', 'Lead_ Actor_Rating', '3D_available', 'Production expense', 'Budget', 'Avg_age_actors', 'Trailer_views', 'Producer_rating', 'Critic_rating', 'Movie_length', 'Time_taken']

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Length: 506, dtype: bool

# %%
2. Menemukan null values

# %%
null_count = len(list(filter(None, df)))
 
print(f"Jumlah nilai elemen null : {null_count}")
# Out:
# Jumlah nilai elemen null : 19

# %%
3. Drop missing value

# %%
df.dropna(how='all')
# Out:
#     Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0             201.264               59.62               462.0  36.524.125
# 1             205.462               69.14               531.0  35.668.655
# 2             205.458               69.14               531.0  39.912.675
# 3             206.474               59.36               542.0    38873.89
# 4              21.381               59.36               542.0  39.701.585
# ..                ...                 ...                 ...         ...
# 501           212.526               78.86               427.0  36.624.115
# 502           209.054               78.86               427.0     33996.6
# 503           212.152               78.86               427.0    38751.68
# 504           221.918               78.86               427.0    37740.67
# 505           209.482               78.86               427.0    33496.65
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
missing_value_count = df.isna().sum()
print(missing_value_count)
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64
